# %% [markdown]
# <a href="https://colab.research.google.com/github/JangHoIk1/Data-analysis-and-image-processing/blob/main/%ED%81%AC%EB%A1%A4%EB%A7%81_2%EC%9E%A5_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Colab에서 Selenium 사용하기

# %% [markdown]
# ##셀레니움 드라이버 설치(코랩)

# %%
#colab에서 셀리니움 이용하기 
# !pip install Selenium
# !apt-get update # to update ubuntu to correctly run apt install
# !apt install chromium-chromedriver #Chrom Driver 설치

# %% [markdown]
# ##셀레니움 드라이버 옵션설정(headless)

# %%
from selenium import webdriver

# 드라버 만들때 크롬옵션을 
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless') #내부 창을 띄울 수 없으므로 설정
chrome_options.add_argument('--no-sandbox')   
chrome_options.add_argument('--disable-dev-shm-usage')

# %% [markdown]
# ##네이버 로그인 클릭

# %%
import time
from bs4 import BeautifulSoup as bs
from selenium.webdriver.common.by import By

# chrom 객체에 driver

# %%
# 검색창에 검색어 "여름여행" 입력 
from selenium.webdriver.common.keys import Keys

# 검색창
#elem = brower.find_element_by_id("query")
elem = brower.find_element(By.ID, ??????????)  # OK

elem.send_keys("여름여행")
elem.send_keys(Keys.ENTER)

# %%
#elem = brower.find_element_by_name("query")
elem = brower.find_element(By.NAME, ?????????)  # OK

elem.send_keys("여름여행")
elem.send_keys(Keys.ENTER)

# %%
#elem = brower.find_element_by_class_name("input_text")
elem = brower.find_element(By.CLASS_NAME, ?????????)  # OK

elem.send_keys("여름여행")
elem.send_keys(Keys.ENTER)
